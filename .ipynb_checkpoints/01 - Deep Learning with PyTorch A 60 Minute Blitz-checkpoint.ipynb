# %% [markdown]
# # Tutorials
#
# https://pytorch.org/tutorials/beginner/deep_learning_60min_blitz.html
#
# ![image-2.png](attachment:image-2.png)
#
# https://www.youtube.com/watch?v=u7x8RXwLKcA

# %% [markdown]
# # Notebooks

# %% [markdown]
# [Tensors](tensor_tutorial.ipynb)

# %% [markdown]
# [Autograd](autograd_tutorial.ipynb)

# %% [markdown]
# [Neural Networks](neural_networks_tutorial.ipynb)

# %% [markdown]
# [classifier](cifar10_tutorial.ipynb)
